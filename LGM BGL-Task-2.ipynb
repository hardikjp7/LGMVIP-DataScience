# %% [markdown]
# # **LGM-VIP Data Science**
# **Beginner level Task-2**
#
# **Stock Market Prediction And Forecasting Using Stacked LSTM**
#
# **Name : Hardik Parmar**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import MinMaxScaler

# %%
data = pd.read_csv('https://raw.githubusercontent.com/mwitiderrick/stockprice/master/NSE-TATAGLOBAL.csv')

# %%
data.head()
# Out:
#          Date    Open    High     Low    Last   Close  Total Trade Quantity  \
# 0  2018-09-28  234.05  235.95  230.20  233.50  233.75               3069914
# 1  2018-09-27  234.55  236.80  231.10  233.80  233.25               5082859
# 2  2018-09-26  240.00  240.00  232.50  235.00  234.25               2240909
# 3  2018-09-25  233.30  236.75  232.00  236.25  236.10               2349368
# 4  2018-09-24  233.55  239.20  230.75  234.00  233.30               3423509
#
#    Turnover (Lacs)
# 0          7162.35
# 1         11859.95
# 2          5248.60
# 3          5503.90
# 4          7999.55

# %%
data.tail()
# Out:
#             Date   Open    High     Low    Last   Close  Total Trade Quantity  \
# 2030  2010-07-27  117.6  119.50  112.00  118.80  118.65                586100
# 2031  2010-07-26  120.1  121.00  117.10  117.10  117.60                658440
# 2032  2010-07-23  121.8  121.95  120.25  120.35  120.65                281312
# 2033  2010-07-22  120.3  122.00  120.25  120.75  120.90                293312
# 2034  2010-07-21  122.1  123.00  121.05  121.10  121.55                658666
#
#       Turnover (Lacs)
# 2030           694.98
# 2031           780.01
# 2032           340.31
# 2033           355.17
# 2034           803.56

# %%
data['Date'] = pd.to_datetime(data['Date'])
df = data.sort_values(by='Date')
df.head()
# Out:
#            Date   Open    High     Low    Last   Close  Total Trade Quantity  \
# 2034 2010-07-21  122.1  123.00  121.05  121.10  121.55                658666
# 2033 2010-07-22  120.3  122.00  120.25  120.75  120.90                293312
# 2032 2010-07-23  121.8  121.95  120.25  120.35  120.65                281312
# 2031 2010-07-26  120.1  121.00  117.10  117.10  117.60                658440
# 2030 2010-07-27  117.6  119.50  112.00  118.80  118.65                586100
#
#       Turnover (Lacs)
# 2034           803.56
# 2033           355.17
# 2032           340.31
# 2031           780.01
# 2030           694.98

# %%
df.reset_index(inplace=True)

# %%
df.head()
# Out:
#    index       Date   Open    High     Low    Last   Close  \
# 0   2034 2010-07-21  122.1  123.00  121.05  121.10  121.55
# 1   2033 2010-07-22  120.3  122.00  120.25  120.75  120.90
# 2   2032 2010-07-23  121.8  121.95  120.25  120.35  120.65
# 3   2031 2010-07-26  120.1  121.00  117.10  117.10  117.60
# 4   2030 2010-07-27  117.6  119.50  112.00  118.80  118.65
#
#    Total Trade Quantity  Turnover (Lacs)
# 0                658666           803.56
# 1                293312           355.17
# 2                281312           340.31
# 3                658440           780.01
# 4                586100           694.98

# %%
plt.plot(df['Close'])

# %%
df1 = df['Close']

# %%
scaler = MinMaxScaler(feature_range=(0,1))
df1 = scaler.fit_transform(np.array(df1).reshape(-1,1))
df1
# Out:
# array([[0.16584967],
#        [0.16319444],
#        [0.1621732 ],
#        ...,
#        [0.62622549],
#        [0.62214052],
#        [0.62418301]])

# %%
training_size = int(len(df1)*0.70)
test_size = len(df1) - training_size


train_data = df1[0:training_size,:]
test_data = df1[training_size:len(df1), :1]

# %%
training_size, test_size
# Out:
# (1424, 611)

# %%
def datasetCrtd(dataset, time_step=1):
  dataX, dataY = [], []
  for i in range(len(dataset)-time_step-1):
    a = dataset[i:(i+time_step), 0]
    dataX.append(a)
    dataY.append(dataset[i + time_step, 0])

  return np.array(dataX), np.array(dataY)

# %%
time_step = 100
X_train, y_train = datasetCrtd(train_data, time_step)
X_test, ytest = datasetCrtd(test_data, time_step)

# %%
print(X_train.shape), print(y_train.shape)
# Out:
# (1323, 100)
# (1323,)
# (None, None)

# %%
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM

# %%
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(100,1)))
model.add(LSTM(50, return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 100, 50)           10400
#
#  lstm_1 (LSTM)               (None, 100, 50)           20200
#
#  lstm_2 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train, y_train, validation_split=0.1, epochs=60, batch_size=64, verbose=1)
# Out:
# Epoch 1/60
# 19/19 [==============================] - 12s 305ms/step - loss: 0.0115 - val_loss: 0.0011
# Epoch 2/60
# 19/19 [==============================] - 3s 176ms/step - loss: 0.0018 - val_loss: 0.0012
# Epoch 3/60
# 19/19 [==============================] - 3s 174ms/step - loss: 8.7779e-04 - val_loss: 0.0011
# Epoch 4/60
# 19/19 [==============================] - 4s 236ms/step - loss: 8.0748e-04 - val_loss: 0.0010
# Epoch 5/60
# 19/19 [==============================] - 3s 175ms/step - loss: 7.7055e-04 - val_loss: 0.0011
# Epoch 6/60
# 19/19 [==============================] - 3s 177ms/step - loss: 7.7629e-04 - val_loss: 9.8537e-04
# Epoch 7/60
# 19/19 [==============================] - 4s 214ms/step - loss: 7.3922e-04 - val_loss: 9.8447e-04
# Epoch 8/60
# 19/19 [==============================] - 4s 186ms/step - loss: 7.2443e-04 - val_loss: 9.1047e-04
# Epoch 9/60
# 19/19 [==============================] - 3s 176ms/step - loss: 7.5563e-04 - val_loss: 9.6577e-04
# Epoch 10/60
# 19/19 [==============================] - 3s 172ms/step - loss: 6.8415e-04 - val_loss: 8.4690e-04
# Epoch 11/60
# 19/19 [==============================] - 4s 239ms/step - loss: 6.8907e-04 - val_loss: 8.0623e-04
# Epoch 12/60
# 19/19 [==============================] - 3s 173ms/step - loss: 6.5483e-04 - val_loss: 7.8153e-04
# Epoch 13/60
# 19/19 [==============================] - 3s 173ms/step - loss: 6.4395e-04 - val_loss: 8.1840e-04
# Epoch 14/60
# 19/19 [==============================] - 4s 218ms/step - loss: 6.2384e-04 - val_loss: 7.5919e-04
# Epoch 15/60
# 19/19 [==============================] - 4s 186ms/step - loss: 6.3619e-04 - val_loss: 9.4391e-04
# Epoch 16/60
# 19/19 [==============================] - 3s 176ms/step - loss: 6.3814e-04 - val_loss: 6.9840e-04
# Epoch 17/60
# 19/19 [==============================] - 5s 289ms/step - loss: 5.6710e-04 - val_loss: 6.3909e-04
# Epoch 18/60
# 19/19 [==============================] - 4s 196ms/step - loss: 5.5373e-04 - val_loss: 6.2111e-04
# Epoch 19/60
# 19/19 [==============================] - 3s 177ms/step - loss: 5.4123e-04 - val_loss: 5.9804e-04
# Epoch 20/60
# 19/19 [==============================] - 3s 173ms/step - loss: 5.3815e-04 - val_loss: 5.9205e-04
# Epoch 21/60
# 19/19 [==============================] - 5s 241ms/step - loss: 5.2928e-04 - val_loss: 5.5351e-04
# Epoch 22/60
# 19/19 [==============================] - 4s 197ms/step - loss: 5.4421e-04 - val_loss: 6.1711e-04
# Epoch 23/60
# 19/19 [==============================] - 3s 171ms/step - loss: 5.0018e-04 - val_loss: 5.4615e-04
# Epoch 24/60
# 19/19 [==============================] - 4s 224ms/step - loss: 5.0688e-04 - val_loss: 5.1823e-04
# Epoch 25/60
# 19/19 [==============================] - 3s 177ms/step - loss: 4.8692e-04 - val_loss: 6.9365e-04
# Epoch 26/60
# 19/19 [==============================] - 3s 173ms/step - loss: 5.0755e-04 - val_loss: 5.5619e-04
# Epoch 27/60
# 19/19 [==============================] - 3s 173ms/step - loss: 4.7537e-04 - val_loss: 5.0349e-04
# Epoch 28/60
# 19/19 [==============================] - 4s 237ms/step - loss: 4.9550e-04 - val_loss: 4.7362e-04
# Epoch 29/60
# 19/19 [==============================] - 3s 174ms/step - loss: 4.4754e-04 - val_loss: 4.5794e-04
# Epoch 30/60
# 19/19 [==============================] - 3s 173ms/step - loss: 4.2391e-04 - val_loss: 4.3613e-04
# Epoch 31/60
# 19/19 [==============================] - 4s 225ms/step - loss: 4.2086e-04 - val_loss: 4.6328e-04
# Epoch 32/60
# 19/19 [==============================] - 4s 179ms/step - loss: 4.0535e-04 - val_loss: 4.4134e-04
# Epoch 33/60
# 19/19 [==============================] - 3s 172ms/step - loss: 3.9499e-04 - val_loss: 3.9729e-04
# Epoch 34/60
# 19/19 [==============================] - 3s 175ms/step - loss: 4.1957e-04 - val_loss: 5.1077e-04
# Epoch 35/60
# 19/19 [==============================] - 4s 235ms/step - loss: 4.0442e-04 - val_loss: 4.0330e-04
# Epoch 36/60
# 19/19 [==============================] - 3s 173ms/step - loss: 3.9960e-04 - val_loss: 3.9308e-04
# Epoch 37/60
# 19/19 [==============================] - 3s 176ms/step - loss: 3.9520e-04 - val_loss: 3.6033e-04
# Epoch 38/60
# 19/19 [==============================] - 4s 222ms/step - loss: 3.6034e-04 - val_loss: 3.9565e-04
# Epoch 39/60
# 19/19 [==============================] - 4s 180ms/step - loss: 3.6378e-04 - val_loss: 4.1582e-04
# Epoch 40/60
# 19/19 [==============================] - 3s 172ms/step - loss: 3.4113e-04 - val_loss: 4.2025e-04
# Epoch 41/60
# 19/19 [==============================] - 3s 174ms/step - loss: 3.4162e-04 - val_loss: 3.1249e-04
# Epoch 42/60
# 19/19 [==============================] - 4s 237ms/step - loss: 3.3106e-04 - val_loss: 2.9861e-04
# Epoch 43/60
# 19/19 [==============================] - 3s 173ms/step - loss: 3.2674e-04 - val_loss: 2.8655e-04
# Epoch 44/60
# 19/19 [==============================] - 3s 172ms/step - loss: 3.0152e-04 - val_loss: 2.7259e-04
# Epoch 45/60
# 19/19 [==============================] - 4s 213ms/step - loss: 2.9588e-04 - val_loss: 3.1401e-04
# Epoch 46/60
# 19/19 [==============================] - 4s 189ms/step - loss: 2.8492e-04 - val_loss: 2.6341e-04
# Epoch 47/60
# 19/19 [==============================] - 3s 173ms/step - loss: 2.8019e-04 - val_loss: 2.4827e-04
# Epoch 48/60
# 19/19 [==============================] - 3s 174ms/step - loss: 2.7221e-04 - val_loss: 2.4231e-04
# Epoch 49/60
# 19/19 [==============================] - 4s 239ms/step - loss: 2.7058e-04 - val_loss: 2.6865e-04
# Epoch 50/60
# 19/19 [==============================] - 3s 175ms/step - loss: 2.9334e-04 - val_loss: 2.2584e-04
# Epoch 51/60
# 19/19 [==============================] - 3s 173ms/step - loss: 2.8807e-04 - val_loss: 2.4413e-04
# Epoch 52/60
# 19/19 [==============================] - 4s 217ms/step - loss: 2.5657e-04 - val_loss: 2.7650e-04
# Epoch 53/60
# 19/19 [==============================] - 4s 192ms/step - loss: 2.5361e-04 - val_loss: 2.4255e-04
# Epoch 54/60
# 19/19 [==============================] - 3s 174ms/step - loss: 2.4997e-04 - val_loss: 2.1331e-04
# Epoch 55/60
# 19/19 [==============================] - 3s 175ms/step - loss: 2.2371e-04 - val_loss: 1.9574e-04
# Epoch 56/60
# 19/19 [==============================] - 4s 235ms/step - loss: 2.3207e-04 - val_loss: 2.1827e-04
# Epoch 57/60
# 19/19 [==============================] - 3s 177ms/step - loss: 2.4122e-04 - val_loss: 1.9890e-04
# Epoch 58/60
# 19/19 [==============================] - 3s 171ms/step - loss: 2.2061e-04 - val_loss: 1.8624e-04
# Epoch 59/60
# 19/19 [==============================] - 4s 214ms/step - loss: 2.2715e-04 - val_loss: 2.0390e-04
# Epoch 60/60
# 19/19 [==============================] - 4s 186ms/step - loss: 2.2042e-04 - val_loss: 1.7823e-04

# %%
test_predict = model.predict(X_test)
# Out:
# 16/16 [==============================] - 4s 40ms/step

# %%
test_predict1 = scaler.inverse_transform(test_predict)

# %%
test_predict1
# Out:
# array([[142.03383 ],
#        [142.26329 ],
#        [141.4786  ],
#        [139.01012 ],
#        [137.31433 ],
#        [136.62103 ],
#        [137.56288 ],
#        [139.02644 ],
#        [139.5294  ],
#        [139.31667 ],
#        [139.14407 ],
#        [140.22908 ],
#        [141.01993 ],
#        [142.52388 ],
#        [144.64302 ],
#        [142.97546 ],
#        [140.70514 ],
#        [140.14922 ],
#        [140.56505 ],
#        [145.09578 ],
#        [149.4253  ],
#        [151.81482 ],
#        [152.43153 ],
#        [150.65343 ],
#        [150.32494 ],
#        [149.96803 ],
#        [150.20013 ],
#        [151.66927 ],
#        [152.39468 ],
#        [152.4584  ],
#        [152.82678 ],
#        [151.78838 ],
#        [148.76842 ],
#        [143.38144 ],
#        [139.80334 ],
#        [138.45364 ],
#        [138.36021 ],
#        [137.63087 ],
#        [135.60794 ],
#        [132.27322 ],
#        [129.81673 ],
#        [128.53343 ],
#        [126.55529 ],
#        [125.68552 ],
#        [123.82893 ],
#        [121.40797 ],
#        [120.60377 ],
#        [120.25839 ],
#        [120.47414 ],
#        [119.70717 ],
#        [118.92296 ],
#        [118.5157  ],
#        [117.767   ],
#        [117.81824 ],
#        [118.987526],
#        [120.67519 ],
#        [122.57086 ],
#        [123.46533 ],
#        [123.368904],
#        [123.37627 ],
#        [123.48019 ],
#        [123.30074 ],
#        [123.42206 ],
#        [123.74893 ],
#        [123.939926],
#        [123.99308 ],
#        [123.82031 ],
#        [124.057884],
#        [124.46235 ],
#        [124.808136],
#        [124.168365],
#        [123.247795],
#        [121.9483  ],
#        [120.69014 ],
#        [119.37351 ],
#        [119.31621 ],
#        [119.78501 ],
#        [120.69036 ],
#        [121.77989 ],
#        [123.02758 ],
#        [124.220604],
#        [124.996056],
#        [125.48381 ],
#        [125.532036],
#        [125.35194 ],
#        [125.05132 ],
#        [125.657166],
#        [125.9731  ],
#        [126.84061 ],
#        [127.627594],
#        [128.07306 ],
#        [128.50659 ],
#        [129.37949 ],
#        [129.06071 ],
#        [128.5481  ],
#        [128.37039 ],
#        [128.4358  ],
#        [128.83893 ],
#        [129.66092 ],
#        [129.97772 ],
#        [130.23444 ],
#        [132.6699  ],
#        [136.91748 ],
#        [140.90901 ],
#        [142.84917 ],
#        [144.4447  ],
#        [144.70691 ],
#        [144.15613 ],
#        [142.80423 ],
#        [141.34857 ],
#        [139.66263 ],
#        [138.96696 ],
#        [139.15176 ],
#        [140.20442 ],
#        [141.3405  ],
#        [141.55133 ],
#        [140.94525 ],
#        [140.06798 ],
#        [139.1175  ],
#        [140.26389 ],
#        [141.31151 ],
#        [142.47894 ],
#        [143.26764 ],
#        [143.37564 ],
#        [142.64084 ],
#        [141.56293 ],
#        [139.53137 ],
#        [138.53596 ],
#        [138.99507 ],
#        [141.26799 ],
#        [143.6756  ],
#        [145.71872 ],
#        [146.62943 ],
#        [145.64774 ],
#        [147.00829 ],
#        [149.0964  ],
#        [149.6557  ],
#        [149.82884 ],
#        [149.88948 ],
#        [149.7412  ],
#        [149.70657 ],
#        [150.27101 ],
#        [151.22238 ],
#        [152.13608 ],
#        [151.77737 ],
#        [151.05524 ],
#        [151.42595 ],
#        [151.6351  ],
#        [151.13986 ],
#        [150.12375 ],
#        [148.83249 ],
#        [148.6784  ],
#        [149.89482 ],
#        [150.96373 ],
#        [151.67964 ],
#        [151.8561  ],
#        [152.44312 ],
#        [152.4172  ],
#        [152.39201 ],
#        [154.10783 ],
#        [155.47107 ],
#        [155.64566 ],
#        [154.03986 ],
#        [152.39012 ],
#        [152.04288 ],
#        [152.79942 ],
#        [153.43481 ],
#        [153.21472 ],
#        [153.41759 ],
#        [153.7734  ],
#        [153.4293  ],
#        [150.8813  ],
#        [149.02232 ],
#        [147.77791 ],
#        [146.18582 ],
#        [143.93976 ],
#        [142.73209 ],
#        [143.89629 ],
#        [145.28365 ],
#        [146.1353  ],
#        [147.70439 ],
#        [150.14151 ],
#        [152.8867  ],
#        [154.63925 ],
#        [154.3747  ],
#        [154.13673 ],
#        [153.76712 ],
#        [153.37758 ],
#        [152.31384 ],
#        [152.99232 ],
#        [155.15648 ],
#        [157.39398 ],
#        [158.36247 ],
#        [157.63097 ],
#        [156.6145  ],
#        [155.95398 ],
#        [154.96246 ],
#        [152.83803 ],
#        [149.6662  ],
#        [148.01001 ],
#        [147.62419 ],
#        [148.72226 ],
#        [150.44371 ],
#        [151.15988 ],
#        [153.24644 ],
#        [154.22963 ],
#        [155.70631 ],
#        [160.21925 ],
#        [165.54816 ],
#        [170.47285 ],
#        [173.61195 ],
#        [173.89037 ],
#        [173.86072 ],
#        [172.43192 ],
#        [171.59819 ],
#        [169.95032 ],
#        [169.14981 ],
#        [168.39388 ],
#        [168.58832 ],
#        [169.71758 ],
#        [169.19464 ],
#        [168.43584 ],
#        [168.17944 ],
#        [167.38136 ],
#        [165.60823 ],
#        [164.8062  ],
#        [164.75847 ],
#        [166.65186 ],
#        [166.7282  ],
#        [164.16019 ],
#        [159.14182 ],
#        [158.5619  ],
#        [166.41174 ],
#        [181.35587 ],
#        [191.12085 ],
#        [194.72615 ],
#        [194.53351 ],
#        [189.69771 ],
#        [188.29108 ],
#        [188.15765 ],
#        [188.0964  ],
#        [186.9198  ],
#        [189.35725 ],
#        [192.9022  ],
#        [194.86859 ],
#        [193.07281 ],
#        [192.3257  ],
#        [197.03123 ],
#        [201.33554 ],
#        [203.3295  ],
#        [204.35072 ],
#        [205.7507  ],
#        [203.96748 ],
#        [204.15265 ],
#        [204.40263 ],
#        [205.88007 ],
#        [208.62094 ],
#        [209.04707 ],
#        [207.5087  ],
#        [200.50784 ],
#        [193.16393 ],
#        [194.10086 ],
#        [195.01425 ],
#        [197.52556 ],
#        [200.85869 ],
#        [202.9446  ],
#        [202.40852 ],
#        [203.19218 ],
#        [204.023   ],
#        [203.46419 ],
#        [202.61703 ],
#        [202.63892 ],
#        [204.36284 ],
#        [204.93965 ],
#        [204.39957 ],
#        [204.20616 ],
#        [202.56367 ],
#        [200.17467 ],
#        [198.20541 ],
#        [200.936   ],
#        [201.92848 ],
#        [203.78908 ],
#        [210.5699  ],
#        [218.67778 ],
#        [222.24567 ],
#        [221.95189 ],
#        [219.37135 ],
#        [216.75214 ],
#        [220.75844 ],
#        [219.79121 ],
#        [217.20285 ],
#        [224.71518 ],
#        [229.4205  ],
#        [228.83334 ],
#        [233.54604 ],
#        [239.65433 ],
#        [242.5012  ],
#        [246.53119 ],
#        [256.75836 ],
#        [261.01373 ],
#        [260.30222 ],
#        [258.84134 ],
#        [260.51102 ],
#        [261.5371  ],
#        [267.9842  ],
#        [267.61426 ],
#        [269.4773  ],
#        [268.9957  ],
#        [265.41183 ],
#        [264.14777 ],
#        [261.79813 ],
#        [266.31717 ],
#        [272.67697 ],
#        [280.7425  ],
#        [276.85684 ],
#        [269.54184 ],
#        [266.40656 ],
#        [268.42953 ],
#        [273.17776 ],
#        [281.4154  ],
#        [284.8469  ],
#        [283.5302  ],
#        [283.1239  ],
#        [285.11276 ],
#        [286.03598 ],
#        [286.6751  ],
#        [292.96307 ],
#        [294.20044 ],
#        [291.8747  ],
#        [290.51492 ],
#        [291.31216 ],
#        [292.75693 ],
#        [296.3448  ],
#        [296.5239  ],
#        [294.80096 ],
#        [293.41287 ],
#        [300.90118 ],
#        [303.4729  ],
#        [298.28998 ],
#        [293.19614 ],
#        [287.22034 ],
#        [287.65695 ],
#        [290.38428 ],
#        [290.86343 ],
#        [288.56418 ],
#        [287.14005 ],
#        [285.39267 ],
#        [286.036   ],
#        [278.5625  ],
#        [272.79895 ],
#        [263.834   ],
#        [259.5859  ],
#        [256.3921  ],
#        [264.06418 ],
#        [269.91074 ],
#        [269.04053 ],
#        [270.2457  ],
#        [268.76596 ],
#        [265.06982 ],
#        [261.04507 ],
#        [255.26138 ],
#        [250.24734 ],
#        [251.71725 ],
#        [252.04633 ],
#        [256.95862 ],
#        [261.74576 ],
#        [263.64948 ],
#        [263.1459  ],
#        [261.41507 ],
#        [260.6733  ],
#        [259.76764 ],
#        [256.35718 ],
#        [257.422   ],
#        [256.53336 ],
#        [260.29498 ],
#        [264.4424  ],
#        [265.80118 ],
#        [265.78662 ],
#        [260.89175 ],
#        [250.7467  ],
#        [247.10576 ],
#        [249.22537 ],
#        [249.42221 ],
#        [248.46468 ],
#        [250.4637  ],
#        [252.90466 ],
#        [250.488   ],
#        [258.42383 ],
#        [262.9016  ],
#        [259.68243 ],
#        [257.61603 ],
#        [257.20615 ],
#        [260.5997  ],
#        [261.6654  ],
#        [260.37027 ],
#        [259.49695 ],
#        [260.5686  ],
#        [264.10837 ],
#        [266.77066 ],
#        [269.0662  ],
#        [270.77417 ],
#        [270.95187 ],
#        [268.75665 ],
#        [267.1114  ],
#        [270.54034 ],
#        [274.4996  ],
#        [276.2891  ],
#        [279.39685 ],
#        [277.69565 ],
#        [271.90414 ],
#        [269.9487  ],
#        [274.75974 ],
#        [275.59262 ],
#        [276.0141  ],
#        [272.08267 ],
#        [270.9908  ],
#        [252.57747 ],
#        [234.2011  ],
#        [228.62683 ],
#        [235.21564 ],
#        [240.0924  ],
#        [240.3555  ],
#        [240.66891 ],
#        [241.9066  ],
#        [244.2199  ],
#        [246.49597 ],
#        [248.20518 ],
#        [246.30727 ],
#        [248.28561 ],
#        [253.0684  ],
#        [252.0479  ],
#        [245.21214 ],
#        [246.49109 ],
#        [251.3048  ],
#        [254.90456 ],
#        [255.71846 ],
#        [253.22546 ],
#        [253.62325 ],
#        [255.90018 ],
#        [261.91367 ],
#        [261.57086 ],
#        [261.02148 ],
#        [255.94897 ],
#        [249.21156 ],
#        [245.33997 ],
#        [247.7266  ],
#        [252.26752 ],
#        [256.15472 ],
#        [256.04263 ],
#        [253.4368  ],
#        [254.71864 ],
#        [253.29807 ],
#        [261.40854 ],
#        [264.8865  ],
#        [260.364   ],
#        [253.52858 ],
#        [256.21924 ],
#        [260.07858 ],
#        [258.68506 ],
#        [254.07042 ],
#        [248.19217 ],
#        [236.99138 ],
#        [234.64906 ],
#        [232.00728 ],
#        [227.86525 ],
#        [229.28719 ],
#        [234.45183 ],
#        [238.90758 ],
#        [234.36145 ],
#        [230.306   ],
#        [230.61832 ],
#        [231.89577 ],
#        [235.1102  ],
#        [230.59514 ],
#        [226.07812 ],
#        [224.35713 ],
#        [227.56187 ],
#        [229.60553 ],
#        [229.2471  ],
#        [228.89574 ],
#        [226.70682 ],
#        [225.69778 ],
#        [227.45514 ],
#        [230.0721  ],
#        [233.28526 ],
#        [235.7932  ],
#        [233.68657 ],
#        [228.2629  ],
#        [222.70802 ],
#        [224.14261 ],
#        [225.38974 ],
#        [226.46063 ],
#        [227.82767 ],
#        [227.52872 ],
#        [228.02858 ],
#        [221.24257 ],
#        [215.18167 ],
#        [212.6523  ],
#        [214.04453 ],
#        [215.6255  ],
#        [213.1147  ],
#        [214.16144 ],
#        [222.1169  ],
#        [229.0709  ],
#        [229.97273 ],
#        [227.63039 ],
#        [225.21426 ],
#        [223.41989 ],
#        [224.51347 ],
#        [225.16437 ]], dtype=float32)

# %%
import math
from sklearn.metrics import mean_squared_error
import sklearn.metrics as metrics
math.sqrt(mean_squared_error(ytest, test_predict))
# Out:
# 0.04220781247467093
